# %% [markdown]
# <a href="https://colab.research.google.com/github/rafli-akbar-eka-saputra/PRAKTIKUM-KOMPUTER-GRAFIS-RAFLI-AKBAR-EKA-SAPUTRA-G.211.24.0011-/blob/main/PRAKTIKUM_6_RAFLI_AKBAR_EKA_SAPUTRA_G_211_24_0011.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import module
import pandas as pd
import seaborn as sns
from google.colab import files
uploaded = files.upload()

# load the csv
data1 = pd.read_csv("nba.csv")

# show first 5 column
data1.head()
data1.tail()

sns.lineplot(data1["Salary"])

#sns.scatterplot(data1['Age'])

#sns.lineplot(x=data1["Age"], y=data1["Salary"])

#sns.lineplot(x=data1['Age'],y=data1[ 'Weight'], hue =data1["Position"])

#sns.scatterplot(x=data1['Age'], y=data1['Weight'], hue =data1["Position"])

#sns.boxplot(x=data1['Age'], y=data1['Weight'])

#sns.pointplot(x = "Age", y = "Weight", data = data1)

#sns.barplot(x ="Age", y ="Weight", data = data1)
# Out:
#      <input type="file" id="files-ef99d3a7-bae8-44b2-8047-27fc1814a7bf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ef99d3a7-bae8-44b2-8047-27fc1814a7bf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
sns.scatterplot(data1['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.lineplot(x=data1["Age"], y=data1["Salary"])
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %%
sns.lineplot(x=data1['Age'],y=data1[ 'Weight'], hue =data1["Position"])
# Out:
# <Axes: xlabel='Age', ylabel='Weight'>

# %%
 sns.scatterplot(x=data1['Age'], y=data1['Weight'], hue =data1["Position"])
# Out:
# <Axes: xlabel='Age', ylabel='Weight'>

# %%
 sns.boxplot(x=data1['Age'], y=data1['Weight'])
# Out:
# <Axes: xlabel='Age', ylabel='Weight'>

# %%
 sns.pointplot(x = "Age", y = "Weight", data = data1)
# Out:
# <Axes: xlabel='Age', ylabel='Weight'>

# %%
sns.barplot(x ="Age", y ="Weight", data = data1)
# Out:
# <Axes: xlabel='Age', ylabel='Weight'>
